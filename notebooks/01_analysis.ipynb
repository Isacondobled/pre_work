# %% [markdown]
# ## Real estate data cleaning with Pandas for efficient analysis
#
# This is a real dataset that was downloaded using web scraping techniques. The data contains records from Fotocasa, one of the most popular real estate websites in Spain. Please do not perform web scraping unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro, and no economic benefit was obtained from it.
#
# It contains thousands of real house listings published on the website www.fotocasa.com. Your goal is to extract as much information as possible with the data science knowledge you have acquired so far.
#
# Let's get started!
#
# - First, let's read and explore the dataset.

# %%
# Step 0. Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 1. Load data
df_raw = pd.read_csv("../real_estate.csv", sep=";")
df_raw.sample(10)
# Out:
#        Unnamed: 0  id_realEstates  isNew                      realEstate_name  \
# 5369         5370       153571338  False                     arty consultores
# 12669       12670       153942749  False                              grupo 3
# 3472         3473       151544097  False            sierra noroeste de madrid
# 13075       13076       153568016  False                           valmodomus
# 7908         7909       152888519  False                  gilmar arturo soria
# 14083       14084       153922602  False                           habita mad
# 9594         9595       153523093  False                          habita zone
# 11381       11382       148486266  False  servicasa inmobiliaria maco henares
# 9804         9805       152406959  False                 globalpiso hortaleza
# 10494       10495       153958132  False                   mayor inmobiliaria
#
#        phone_realEstate                                       url_inmueble  \
# 5369        912180512.0  https://www.fotocasa.es/es/comprar/vivienda/al...
# 12669       918009586.0  https://www.fotocasa.es/es/comprar/vivienda/al...
# 3472        911798135.0  https://www.fotocasa.es/es/comprar/vivienda/al...
# 13075       925581627.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 7908        911368209.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 14083       918007061.0  https://www.fotocasa.es/es/comprar/vivienda/bo...
# 9594        911367157.0  https://www.fotocasa.es/es/comprar/vivienda/la...
# 11381       916356409.0  https://www.fotocasa.es/es/comprar/vivienda/al...
# 9804        912783942.0  https://www.fotocasa.es/es/comprar/vivienda/va...
# 10494       918007082.0  https://www.fotocasa.es/es/comprar/vivienda/sa...
#
#        rooms  bathrooms  surface    price  ... level4Id level5Id level6Id  \
# 5369     3.0        2.0    126.0   489000  ...        0        0        0
# 12669    2.0        1.0     62.0   210000  ...        0        0        0
# 3472     4.0        4.0    310.0  1390000  ...        0        0        0
# 13075    3.0        2.0    127.0   489000  ...        0        0        0
# 7908     1.0        1.0     55.0   205000  ...        0        0        0
# 14083    2.0        1.0     77.0   157000  ...        0        0        0
# 9594     2.0        1.0     56.0    90000  ...        0        0        0
# 11381    5.0        3.0    242.0   350000  ...        0        0        0
# 9804     2.0        1.0     48.0   171000  ...        0        0        0
# 10494    3.0        1.0      NaN   140900  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 5369         0        0        1          40,45672           -3,86703     NaN
# 12669        0        0        0     40,4383389488      -3,6516653352     NaN
# 3472         0        0        0          40,42664           -3,71814     NaN
# 13075        0        0        1          40,45672           -3,86703     NaN
# 7908         0        0        0          40,45338           -3,66236     NaN
# 14083        0        0        0  40,3818204949172  -3,71028900146484     NaN
# 9594         0        0        0        40,3818288         -3,6662306     NaN
# 11381        0        0        0          40,40308           -3,37165     NaN
# 9804         0        0        0         40,469699          -3,651864     NaN
# 10494        0        0        0          40,47344            -3,3758     NaN
#
#       customZone
# 5369         NaN
# 12669        NaN
# 3472         NaN
# 13075        NaN
# 7908         NaN
# 14083        NaN
# 9594         NaN
# 11381        NaN
# 9804         NaN
# 10494        NaN
#
# [10 rows x 37 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15335 entries, 0 to 15334
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        15335 non-null  int64
#  1   id_realEstates    15335 non-null  int64
#  2   isNew             15335 non-null  bool
#  3   realEstate_name   15325 non-null  object
#  4   phone_realEstate  14541 non-null  float64
#  5   url_inmueble      15335 non-null  object
#  6   rooms             14982 non-null  float64
#  7   bathrooms         14990 non-null  float64
#  8   surface           14085 non-null  float64
#  9   price             15335 non-null  int64
#  10  date              15335 non-null  object
#  11  description       15193 non-null  object
#  12  address           15335 non-null  object
#  13  country           15335 non-null  object
#  14  level1            15335 non-null  object
#  15  level2            15335 non-null  object
#  16  level3            15335 non-null  object
#  17  level4            8692 non-null   object
#  18  level5            15335 non-null  object
#  19  level6            708 non-null    object
#  20  level7            13058 non-null  object
#  21  level8            6756 non-null   object
#  22  upperLevel        15335 non-null  object
#  23  countryId         15335 non-null  int64
#  24  level1Id          15335 non-null  int64
#  25  level2Id          15335 non-null  int64
#  26  level3Id          15335 non-null  int64
#  27  level4Id          15335 non-null  int64
#  28  level5Id          15335 non-null  int64
#  29  level6Id          15335 non-null  int64
#  30  level7Id          15335 non-null  int64
#  31  level8Id          15335 non-null  int64
#  32  accuracy          15335 non-null  int64
#  33  latitude          15335 non-null  object
#  34  longitude         15335 non-null  object
#  35  zipCode           0 non-null      float64
#  36  customZone        0 non-null      float64
# dtypes: bool(1), float64(6), int64(13), object(17)
# memory usage: 4.2+ MB

# %%
# Step 2. Preprocessing  
df_baking = df_raw.copy()
df_baking = df_baking.iloc[:,1:-2]
df_baking["date"] = pd.to_datetime(df_baking["date"], errors="coerce")
df_baking.columns = df_baking.columns.str.lower()
df_baking = df_baking.drop(columns=["country","countryid","level1id","level2id","level3id","level4id","level5id","level6id","level7id","level8id","accuracy"])
df_baking["id_realestates"] = df_baking["id_realestates"].astype("category")
df_baking["phone_realestate"] = df_baking["phone_realestate"].astype("category")
df_baking["realestate_name"] = df_baking["realestate_name"].astype("category")
df_baking["url_inmueble"] = df_baking["url_inmueble"].astype("category")
df_baking["address"] = df_baking["address"].astype("category")
df_baking["description"] = df_baking["description"].astype("category")
df_baking["latitude"] = df_baking["latitude"].str.replace(",",".")
df_baking["latitude"] = df_baking["latitude"].astype(float)
df_baking["longitude"] = df_baking["longitude"].str.replace(",",".")
df_baking["longitude"] = df_baking["longitude"].astype(float)
df_baking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15335 entries, 0 to 15334
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_realestates    15335 non-null  category
#  1   isnew             15335 non-null  bool
#  2   realestate_name   15325 non-null  category
#  3   phone_realestate  14541 non-null  category
#  4   url_inmueble      15335 non-null  category
#  5   rooms             14982 non-null  float64
#  6   bathrooms         14990 non-null  float64
#  7   surface           14085 non-null  float64
#  8   price             15335 non-null  int64
#  9   date              683 non-null    datetime64[ns, UTC]
#  10  description       15193 non-null  category
#  11  address           15335 non-null  category
#  12  level1            15335 non-null  object
#  13  level2            15335 non-null  object
#  14  level3            15335 non-null  object
#  15  level4            8692 non-null   object
#  16  level5            15335 non-null  object
#  17  level6            708 non-null    object
#  18  level7            13058 non-null  object
#  19  level8            6756 non-null   object
#  20  upperlevel        15335 non-null  object
#  21  latitude          15335 non-null  float64
#  22  longitude         15335 non-null  float64
# dtypes: bool(1), category(6), datetime64[ns, UTC](1), float64(5), int64(1), object(9)
# memory usage: 3.4+ MB

# %%
df = df_baking.copy()
df.sample(5,random_state=2025)
# Out:
#       id_realestates  isnew                       realestate_name  \
# 11956      153704529  False                            habita mad
# 7285       150530836  False  desarrollo de viviendas nueva ciudad
# 14035      153921873  False                             garsierra
# 10823      150512853  False                            covibarges
# 5778       148949209  False                                 urban
#
#       phone_realestate                                       url_inmueble  \
# 11956      918007061.0  https://www.fotocasa.es/es/comprar/vivienda/gu...
# 7285       916358709.0  https://www.fotocasa.es/vivienda/alcala-de-hen...
# 14035      912179623.0  https://www.fotocasa.es/es/comprar/vivienda/ti...
# 10823      912175971.0  https://www.fotocasa.es/vivienda/arganda-del-r...
# 5778       912780256.0  https://www.fotocasa.es/es/comprar/vivienda/pa...
#
#        rooms  bathrooms  surface   price date  ...  level2  \
# 11956    3.0        1.0     72.0  214000  NaT  ...  Madrid
# 7285     3.0        2.0    112.0  243800  NaT  ...  Madrid
# 14035    1.0        2.0     72.0   85000  NaT  ...  Madrid
# 10823    3.0        2.0    107.0  255000  NaT  ...  Madrid
# 5778     4.0        4.0      NaN  439000  NaT  ...  Madrid
#
#                                level3                          level4  \
# 11956                 Madrid, Zona de                             NaN
# 7285               Zona Sur de Madrid                  Parla, Zona de
# 14035            Corredor del Henares  Camarma de Esteruelas, Zona de
# 10823  Madrid Sureste - Cuenca Tajuña      Rivas-Vaciamadrid, Zona de
# 5778                    Zona Suroeste                Brunete, Zona de
#
#                       level5 level6                level7    level8  \
# 11956         Madrid Capital    NaN             Hortaleza  Canillas
# 7285                   Parla    NaN                Centro       NaN
# 14035  Camarma de Esteruelas    NaN                   NaN       NaN
# 10823      Rivas-vaciamadrid    NaN  Rivas Urbanizaciones       NaN
# 5778                 Brunete    NaN                   NaN       NaN
#
#                   upperlevel   latitude longitude
# 11956               Canillas  40.464490 -3.632650
# 7285                  Centro  40.237680 -3.774230
# 14035  Camarma de Esteruelas  40.550675 -3.377295
# 10823   Rivas Urbanizaciones  40.382190 -3.530690
# 5778                 Brunete  40.397230 -3.998940
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Exercise 01. What is the most expensive house in the entire dataset?

# %%
#df_baking["price"].max()
#df_baking[df_baking["price"] == 8500000]
#df_baking.sort_values(by="price", ascending=False).iloc[0,:]
df.sort_values(by="price", ascending=False).head(1)
# Out:
#       id_realestates  isnew             realestate_name phone_realestate  \
# 13110      132042636  False  engel volkers torrelodones      911798512.0
#
#                                             url_inmueble  rooms  bathrooms  \
# 13110  https://www.fotocasa.es/es/comprar/vivienda/vi...   19.0        NaN
#
#        surface    price date  ...  level2         level3  \
# 13110      NaN  8500000  NaT  ...  Madrid  Zona Noroeste
#
#                      level4       level5 level6              level7 level8  \
# 13110  El Escorial, Zona de  El Escorial    NaN  Centro - Manquilla    NaN
#
#                upperlevel  latitude longitude
# 13110  Centro - Manquilla  40.58308 -4.129519
#
# [1 rows x 23 columns]

# %% [markdown]
# ## Exercise 02. What is the cheapest house in the dataset? (★☆☆)
#
# This exercise is similar to the previous one, except now we are looking for the house with the lowest price. Remember to print the address and price of the selected house. For example:

# %%
df[df["price"] != 0].sort_values(by="price", ascending=True)[["address","price"]].head(1)
# Out:
#               address  price
# 7491  Berlin, Coslada    600

# %% [markdown]
# ## Exercise 03. What is the largest and smallest house in the dataset? (★☆☆)
# Print the address and area of the selected houses. For example:
#
# The largest house is located at Calle Gran Vía, Nº38, and its area is 5000 square meters.
#
# The smallest house is located at Calle Mayor, Nº12, and its area is 200 square meters.
#
# This exercise is similar to the previous one, but we are looking for the largest and smallest houses based on their area.

# %%
df.sort_values(by="surface", ascending=True).head(1)[["address","surface"]]
df.sort_values(by="surface", ascending=False).head(1)[["address","surface"]]
# Out:
#                address   surface
# 6794  Sevilla la Nueva  249000.0

# %% [markdown]
# Exercise 04. How many unique populations are in the dataset? (★☆☆)
# Count the number of unique populations in the 'level5' column and print the names of the populations separated by commas. For example:
#
# > print(populations)
#
# population1, population2, population3, ...

# %%
list_population = df["level5"].unique().tolist()
list_population_count = df["level5"].nunique()
print(f"Hay {list_population_count} ciudades y estas son: {", ".join(list_population)}")
# Out:
# Hay 168 ciudades y estas son: Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bustarviejo, Manzanares El Real, Carabaña, Casarrubuelos, Cercedilla, Fresnedillas de la Oliva, Valdemaqueda, Robledo de Chavela, Miraflores de la Sierra, Humanes de Madrid, Valdetorres de Jarama, San Agustín del Guadalix, Ciempozuelos, Camarma de Esteruelas, Torres de la Alameda, Talamanca de Jarama, El Atazar, Hoyo de Manzanares, El Boalo - Cerceda – Mataelpino, El Álamo, Valdilecha, Valdeolmos-Alalpardo, Guadalix de la Sierra, Belmonte de Tajo, El Vellón, Brunete, Redueña, Morata de Tajuña, Tielmes, Gargantilla del Lozoya, Meco, Venturada, Quijorna, Cenicientos, Torrejón de Velasco, Navacerrada, Santa María de la Alameda, Orusco de Tajuña, Daganzo de Arriba, Villamanta, Anchuelo, Valdaracete, Ajalvir, Los Santos de la Humosa, Villamanrique de Tajo, Colmenar de Oreja, Villa del Prado, Fuentidueña de Tajo, Colmenar del Arroyo, Valdelaguna, Cubas de la Sagra, Valdeavero, Aldea del Fresno, Ribatejada, Torrelaguna, Batres, Pezuela de las Torres, Colmenarejo, Serranillos del Valle, Cobeña, Soto del Real, El Berrueco, Villanueva de Perales, Fresno de Torote - Serracines, Pozuelo del Rey, Pelayos de la Presa, La Cabrera, Nuevo Baztán, Perales de Tajuña, Villaconejos, Villarejo de Salvanés, Cadalso de los Vidrios, Santorcaz, Madarcos, Garganta de los Montes, Puentes Viejas, Torremocha de Jarama, Valdemanco, Braojos, Lozoyuela-navas-sieteiglesias, Piñuécar-gandullas, Valdepiélagos, Valverde de Alcalá, Villar del Olmo, Villamantilla, Horcajo de la Sierra, Gascones, Zarzalejo, Villavieja del Lozoya, Brea de Tajo, Estremera, Chapinería, Navarredonda, Patones, Ambite, Navalafuente, Lozoya, Canencia, Cabanillas de la Sierra, Buitrago del Lozoya, Fresno de Torote, Robregordo, Pinilla del Valle, Rascafría, La Hiruela, Montejo de la Sierra

# %% [markdown]
# ## Exercise 05. Does the dataset contain null values (NAs)? (★☆☆)
# Print a boolean (True or False) to check if there are null values, followed by the columns that contain NAs.

# %%
df.isna().sum()
# Out:
# id_realestates          0
# isnew                   0
# realestate_name        10
# phone_realestate      794
# url_inmueble            0
# rooms                 353
# bathrooms             345
# surface              1250
# price                   0
# date                14652
# description           142
# address                 0
# level1                  0
# level2                  0
# level3                  0
# level4               6643
# level5                  0
# level6              14627
# level7               2277
# level8               8579
# upperlevel              0
# latitude                0
# longitude               0
# dtype: int64

# %% [markdown]
# ## Exercise 06. Remove the null values (NAs) from the dataset, if applicable (★★☆)
# After removing the null values, compare the size of the DataFrame before and after the removal.

# %%
df.dropna(subset=["surface"])
# Out:
#       id_realestates  isnew                    realestate_name  \
# 0          153771986  False            ferrari 57 inmobiliaria
# 2          153430440  False                 look find boadilla
# 3          152776331  False  tecnocasa fuenlabrada ferrocarril
# 4          153180188  False            ferrari 57 inmobiliaria
# 5          153934794  False                            expimad
# ...              ...    ...                                ...
# 15330      153901377  False                infocasa consulting
# 15331      150394373  False                inmobiliaria pulpon
# 15332      153901397  False             tecnocasa torrelodones
# 15333      152607440  False                inmobiliaria pulpon
# 15334      153901356  False                infocasa consulting
#
#       phone_realestate                                       url_inmueble  \
# 0          912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2          916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3          916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4          912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 5          912780412.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                ...                                                ...
# 15330      911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331      912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332      912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333      912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334      911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price                                date  \
# 0        3.0        2.0    103.0  195000 2019-12-28 18:27:15.997502700+00:00
# 2        2.0        2.0     99.0  390000 2019-12-28 18:27:15.997502700+00:00
# 3        3.0        1.0     86.0   89000 2019-12-28 18:27:15.997502700+00:00
# 4        2.0        2.0    106.0  172000 2019-12-28 18:27:15.997502700+00:00
# 5        2.0        1.0     70.0  315000 2019-12-28 18:27:15.968054700+00:00
# ...      ...        ...      ...     ...                                 ...
# 15330    2.0        1.0     96.0  259470                                 NaT
# 15331    3.0        1.0    150.0  165000                                 NaT
# 15332    4.0        2.0    175.0  495000                                 NaT
# 15333    3.0        2.0    101.0  195000                                 NaT
# 15334    3.0        2.0    152.0  765000                                 NaT
#
#        ...  level2                          level3  \
# 0      ...  Madrid  Madrid Sureste - Cuenca Tajuña
# 2      ...  Madrid                   Zona Noroeste
# 3      ...  Madrid              Zona Sur de Madrid
# 4      ...  Madrid  Madrid Sureste - Cuenca Tajuña
# 5      ...  Madrid                   Zona Noroeste
# ...    ...     ...                             ...
# 15330  ...  Madrid                 Madrid, Zona de
# 15331  ...  Madrid  Madrid Sureste - Cuenca Tajuña
# 15332  ...  Madrid                   Zona Noroeste
# 15333  ...  Madrid  Madrid Sureste - Cuenca Tajuña
# 15334  ...  Madrid                 Madrid, Zona de
#
#                                 level4                  level5 level6  \
# 0             Arganda del Rey, Zona de         Arganda del Rey    NaN
# 2          Boadilla del Monte, Zona de      Boadilla del Monte    NaN
# 3                 Fuenlabrada, Zona de             Fuenlabrada    NaN
# 4             Arganda del Rey, Zona de         Arganda del Rey    NaN
# 5         Las Rozas de Madrid, Zona de     Las Rozas de Madrid    NaN
# ...                                ...                     ...    ...
# 15330                              NaN          Madrid Capital    NaN
# 15331  Velilla de San Antonio, Zona de  Velilla de San Antonio    NaN
# 15332            Torrelodones, Zona de            Torrelodones    NaN
# 15333  Velilla de San Antonio, Zona de  Velilla de San Antonio    NaN
# 15334                              NaN          Madrid Capital    NaN
#
#                        level7               level8              upperlevel  \
# 0                     Perlita                  NaN                 Perlita
# 2                    Sector B                  NaN                Sector B
# 3                      Centro                  NaN                  Centro
# 4                      Centro                  NaN                  Centro
# 5      El Pinar - Punta Galea                  NaN  El Pinar - Punta Galea
# ...                       ...                  ...                     ...
# 15330                  Tetuán           Berruguete              Berruguete
# 15331                     NaN                  NaN  Velilla de San Antonio
# 15332           Casco Antiguo                  NaN           Casco Antiguo
# 15333                     NaN                  NaN  Velilla de San Antonio
# 15334                  Tetuán  Castillejos - Cuzco     Castillejos - Cuzco
#
#         latitude longitude
# 0      40.294828 -3.444024
# 2      40.411565 -3.906623
# 3      40.285379 -3.795081
# 4      40.299877 -3.452263
# 5      40.533910 -3.894450
# ...          ...       ...
# 15330  40.454160 -3.702860
# 15331  40.366520 -3.489510
# 15332  40.574440 -3.921240
# 15333  40.369670 -3.481050
# 15334  40.457730 -3.690680
#
# [14085 rows x 23 columns]

# %% [markdown]
# ## Exercise 07. What is the average price in the population of "Arroyomolinos (Madrid)"? (★★☆)
# Print the value obtained from the 'level5' column.

# %%
mean_price = df[df["level5"] == "Arroyomolinos (Madrid)"]["price"].mean()
print(f"El precio promedio en la poblacion de Arroyomolinos es de {mean_price}")
# Out:
# El precio promedio en la poblacion de Arroyomolinos es de 294541.59854014596

# %% [markdown]
# ## Exercise 08. Plot the histogram of prices for the population of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
# Print the histogram of the prices and write a brief analysis of the plot in the Markdown cell.
#
# import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
df[df["level5"] == "Arroyomolinos (Madrid)"]["price"].hist()
plt.title("Histograma de los precios de Arroyomolinos en madrid")
plt.show()

# %% [markdown]
# ## Exercise 09. Are the average prices of "Valdemorillo" and "Galapagar" the same? (★★☆)
# Print both average prices and then write a conclusion about them.

# %% [markdown]
# ## Exercise 10. Are the average prices per square meter (price/m2) of "Valdemorillo" and "Galapagar" the same? (★★☆)
# Print both average prices and then write a conclusion about it.
#
# Hint: Create a new column called pps (price per square meter) and then analyze th

# %%
city1 = "Valdemorillo"
city2 = "Galapagar"
pps_valdemorillo = df.assign(price_per_area = df["price"]/df["surface"]).query("level5==@city1")["price_per_area"].mean()
pps_galapagar = df.assign(price_per_area = df["price"]/df["surface"]).query("level5==@city2")["price_per_area"].mean()

print(f"El precio promedio de Galapagar es: {pps_galapagar:.1f} y el precio promedio de Valdemorillo es {pps_valdemorillo:.1f}")
# Out:
# El precio promedio de Galapagar es: 1606.3 y el precio promedio de Valdemorillo es 1318.0

# %% [markdown]
# ## Exercise 11. Analyze the relation between the surface and the price of the houses (★★☆)
# Hint: You can make a scatter plot, then write a conclusion about it.

# %%
plt.scatter(df[df["surface"]<10000]["surface"],df[df["surface"]<10000]["price"]/1000)
plt.ylabel("precios del terreno en miles de Euros")
plt.xlabel("area en metros cuadrados")
plt.grid(True)
plt.title("Grafica de dispersion de area por precio")
plt.show()

# %% [markdown]
# ### Exercise 12. How many real estate agencies does the dataset contain? (★★☆)
# Print the obtained value.

# %%
unique_agencies = df["realestate_name"].nunique()
print(f"There are {unique_agencies} unique agencies")
# Out:
# There are 1821 unique agencies

# %% [markdown]
# ### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
# Print both the population and the number of houses.

# %%
df.groupby(by="level5").size().sort_values(ascending=False)
# Out:
# level5
#  Madrid Capital         6643
# Alcalá de Henares        525
# Las Rozas de Madrid      383
# Móstoles                 325
# Getafe                   290
#                         ...
# Montejo de la Sierra       1
# Lozoya                     1
# Pinilla del Valle          1
# Rascafría                  1
# Piñuécar-gandullas         1
# Length: 168, dtype: int64

# %% [markdown]
# ### Exercise 14. Now let's work with the "south belt" of Madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
# Hint: Filter the original DataFrame using the column level5 and the function isin.

# %%
new_df = df[df["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
new_df
# Out:
#       id_realestates  isnew                            realestate_name  \
# 1          153867863  False          tecnocasa fuenlabrada ferrocarril
# 3          152776331  False          tecnocasa fuenlabrada ferrocarril
# 85         153152077  False                    sinergical inmobiliaria
# 94         153995577  False                            viviendas365com
# 109        153586414  False            area uno asesores inmobiliarios
# ...              ...    ...                                        ...
# 15275      153903887  False  aliseda servicios de gestion inmobiliaria
# 15291      151697757  False                                    unipiso
# 15305      153902389  False                             jadein ferrero
# 15322      153871864  False                          gestion comercial
# 15325      153901467  False                              montehogar 68
#
#       phone_realestate                                       url_inmueble  \
# 1          916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3          916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 85                 NaN  https://www.fotocasa.es/es/comprar/vivienda/le...
# 94         911226014.0  https://www.fotocasa.es/es/comprar/vivienda/le...
# 109        912664081.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                ...                                                ...
# 15275      911368198.0  https://www.fotocasa.es/es/comprar/vivienda/al...
# 15291      912788631.0  https://www.fotocasa.es/es/comprar/vivienda/al...
# 15305      914871639.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15322      911220662.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15325      911790675.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price                                date  \
# 1        3.0        1.0      NaN   89000 2019-12-28 18:27:15.997502700+00:00
# 3        3.0        1.0     86.0   89000 2019-12-28 18:27:15.997502700+00:00
# 85       1.0        1.0     50.0  107000    2019-12-28 18:30:53.960102+00:00
# 94       3.0        2.0    120.0  320000    2019-12-28 18:30:53.960102+00:00
# 109      3.0        3.0    142.0  425000 2019-12-28 18:32:32.533794200+00:00
# ...      ...        ...      ...     ...                                 ...
# 15275    3.0        1.0     78.0  138000                                 NaT
# 15291    3.0        2.0    110.0  279000                                 NaT
# 15305    3.0        2.0     85.0  170000                                 NaT
# 15322    3.0        1.0     91.0  112000                                 NaT
# 15325    2.0        2.0     99.0  215000                                 NaT
#
#        ...  level2              level3                level4       level5  \
# 1      ...  Madrid  Zona Sur de Madrid  Fuenlabrada, Zona de  Fuenlabrada
# 3      ...  Madrid  Zona Sur de Madrid  Fuenlabrada, Zona de  Fuenlabrada
# 85     ...  Madrid       Zona Suroeste     Alcorcón, Zona de     Alcorcón
# 94     ...  Madrid  Zona Sur de Madrid      Leganés, Zona de      Leganés
# 109    ...  Madrid       Zona Suroeste     Alcorcón, Zona de     Alcorcón
# ...    ...     ...                 ...                   ...          ...
# 15275  ...  Madrid  Zona Sur de Madrid  Fuenlabrada, Zona de  Fuenlabrada
# 15291  ...  Madrid  Zona Sur de Madrid      Leganés, Zona de      Leganés
# 15305  ...  Madrid  Zona Sur de Madrid  Fuenlabrada, Zona de  Fuenlabrada
# 15322  ...  Madrid  Zona Sur de Madrid  Fuenlabrada, Zona de  Fuenlabrada
# 15325  ...  Madrid  Zona Sur de Madrid  Fuenlabrada, Zona de  Fuenlabrada
#
#       level6                                     level7         level8  \
# 1        NaN                                     Centro            NaN
# 3        NaN                                     Centro            NaN
# 85       NaN                                     Centro  Casco Antiguo
# 94       NaN  Valdepelayo - Montepinos - Arroyo Culebro            NaN
# 109      NaN             Prado Santo Domingo - Ensanche            NaN
# ...      ...                                        ...            ...
# 15275    NaN                                    Loranca            NaN
# 15291    NaN                          Centro de Leganés            NaN
# 15305    NaN                 Fuenlabrada II - El Molino            NaN
# 15322    NaN                                     Centro            NaN
# 15325    NaN                      El Arroyo - La Fuente            NaN
#
#                                       upperlevel   latitude longitude
# 1                                         Centro  40.286740 -3.793510
# 3                                         Centro  40.285379 -3.795081
# 85                                 Casco Antiguo  40.350590 -3.826930
# 94     Valdepelayo - Montepinos - Arroyo Culebro  40.319330 -3.775740
# 109               Prado Santo Domingo - Ensanche  40.331341 -3.831387
# ...                                          ...        ...       ...
# 15275                                    Loranca  40.313810 -3.837330
# 15291                          Centro de Leganés  40.325905 -3.763180
# 15305                 Fuenlabrada II - El Molino  40.288219 -3.809862
# 15322                                     Centro  40.282820 -3.788920
# 15325                      El Arroyo - La Fuente  40.280620 -3.798690
#
# [907 rows x 23 columns]

# %% [markdown]
# ### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in Exercise 14) (★★★)
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
plt.bar(new_df["level5"],new_df["price"].median())
# Out:
# <BarContainer object of 907 artists>

# %% [markdown]
# Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in Exercise 14) (★★★★)
#
# Execute the following cell, and then start coding in the next one. You must implement a simple code that transforms the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps, Marker

# Map centered on south west part of Madrid
map = Map(center=(40.35,-3.8), zoom=11.5, basemap=basemaps.OpenStreetMap.Mapnik)
marker = Marker(location=(new_df["latitude"],new_df["longitude"]))
for index,row in new_df.iterrows():
    lat = row["latitude"]
    lon = row["longitude"]
    marker = Marker(location=(lat,lon))
    map.add(marker)
map
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…
